# %%
from google.colab import auth
auth.authenticate_user()

# %%
BUCKET = 'cto-rnd-deep-autocomplete-bucket1' #@param {type:"string"}
assert BUCKET, '*** Must specify an existing GCS bucket name ***'
output_dir_name = 'roberta_output' #@param {type:"string"}
data_dir_name = 'roberta_data_dir' #@param {type:"string"}
BUCKET_NAME = 'gs://{}'.format(BUCKET)
OUTPUT_DIR = 'gs://{}/{}'.format(BUCKET,output_dir_name)
DATA_DIR = 'gs://{}/{}'.format(BUCKET,data_dir_name)
###mkdir(OUTPUT_DIR)
print(f'# Model output directory: "{OUTPUT_DIR}"')
print(f'# Model output directory: "{DATA_DIR}"')
# Out:
# # Model output directory: "gs://cto-rnd-deep-autocomplete-bucket1/roberta_output"
# # Model output directory: "gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-345849b9-84e2-4d9f-ad69-6cc2e4068053" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-345849b9-84e2-4d9f-ad69-6cc2e4068053">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cached_train_roberta-base_384.7z to cached_train_roberta-base_384.7z

# %%
# !ls -l
# Out:
# total 2783624
# -rw-r--r-- 1 root root       2660 Jun 18 16:13 adc.json
# -rw-r--r-- 1 root root 2746816772 Jun 18 15:21 cached_train_roberta-base_384
# -rw-r--r-- 1 root root  103598419 Jun 18 16:30 cached_train_roberta-base_384.7z
# drwxr-xr-x 1 root root       4096 Jun 17 16:18 sample_data

# %%
!7z e cached_train_roberta-base_384.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 103598419 bytes (99 MiB)
#
# Extracting archive: cached_train_roberta-base_384.7z
# --
# Path = cached_train_roberta-base_384.7z
# Type = 7z
# Physical Size = 103598419
# Headers Size = 178
# Method = LZMA:24
# Solid = -
# Blocks = 1
#
#   0%
# Would you like to replace the existing file:
#   Path:     ./cached_train_roberta-base_384
#   Size:     2746816772 bytes (2620 MiB)
#   Modified: 2020-06-18 15:21:27
# with the file from archive:
#   Path:     cached_train_roberta-base_384
#   Size:     2746816772 bytes (2620 MiB)
#   Modified: 2020-06-18 15:21:27
# ? (Y)es / (N)o / (A)lways / (S)kip all / A(u)to rename all / (Q)uit? Y
#
# Everything is Ok
#
# Size:       2746816772
# Compressed: 103598419

# %%
# !gsutil cp /content/cached_train_roberta-base_384.7z $DATA_DIR
# !gsutil cp /content/cached_train_roberta-base_384 $DATA_DIR
# Out:
# Copying file:///content/cached_train_roberta-base_384.7z [Content-Type=application/x-7z-compressed]...
# \
# Operation completed over 1 objects/98.8 MiB.
# Copying file:///content/cached_train_roberta-base_384 [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# -
# Operation completed over 1 objects/2.6 GiB.

# %%
# !gsutil ls -l $DATA_DIR
# Out:
#         11  2020-06-18T12:05:40Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/
# 2746816772  2020-06-18T16:33:21Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/cached_train_roberta-base_384
#  103598419  2020-06-18T16:32:53Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/cached_train_roberta-base_384.7z
#    4854279  2020-06-18T13:41:11Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/dev-v1.1.json
#    4370528  2020-06-18T12:10:34Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/dev-v2.0.json
#        366  2020-06-18T13:28:27Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/tensor.pt
#        364  2020-06-18T13:32:47Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/tensor_x.pt
#   30288272  2020-06-18T13:41:12Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/train-v1.1.json
#   42123633  2020-06-18T12:10:31Z  gs://cto-rnd-deep-autocomplete-bucket1/roberta_data_dir/train-v2.0.json
# TOTAL: 9 objects, 2932052644 bytes (2.73 GiB)
